# %%
## 代码单元格中以感叹号开头的任何行都将作为shell命令执行
# !echo Hello World!
message = 'this is nitth'
# !echo $message

# %%
# %lsmagic

# %%
## Displaying Matplotlib Plots
# %matplotlib

# %%
## Debugging
# %pdb
raise NotImplementedError()
# %debug

# %%
n = 100
##%time sum(range(n))

# %%
##%%time
total = 0
for i in range(n):
    total += i

# %%
# %%HTML
# %%latex

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = sns.load_dataset('tips')

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(data.total_bill, data.tip)

# %%
sns.set(style="darkgrid")
plt.scatter(data.total_bill, data.tip)

# %%
sns.scatterplot(x="total_bill", y="tip", data=data)

# %%
sns.scatterplot(x="total_bill", y="tip", hue="smoker", data=data)

# %%
sns.scatterplot(x="total_bill", y="tip", hue="size", style="smoker", data=data)

# %%
# %macro -q __hello_world 23
# %store __hello_world
# Out:
# 23 is neither a string nor a macro.
# UsageError: Unknown variable '__hello_world'
